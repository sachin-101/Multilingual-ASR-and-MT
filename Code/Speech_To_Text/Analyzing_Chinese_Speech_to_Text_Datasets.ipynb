# %% [markdown]
# ### Analyzing Chinese/Mandarin Speech-to-Text Datasets
# http://www.openslr.org/resources.php
#
# I listened to around 10-15 audio clips from each of the datasets, and compared the given transcript and Google Translate transcript of the audio. The audio with better quality, length and matching transcripts are selected.

# %%
import IPython
import os
import random
import pandas as pd

# %% [markdown]
# #### 1. Ch1
#
# About this resource:
# This free Chinese Mandarin speech corpus set is released by Shanghai Primewords Information Technology Co., Ltd.
#
# The corpus is recorded by smart mobile phones from 296 native Chinese speakers. The transcription accuracy is larger than 98%, at the confidence level of 95%. It is free for academic use.
#
# The mapping between the transcript and utterance is given in JSON format.
#
# You can cite the data using the following BibTeX entry:
#
#     @misc{primewords_201801,
#     title={Primewords Chinese Corpus Set 1},
#     author={Primewords Information Technology Co., Ltd.},
#     year={2018},
#     note={\url{https://www.primewords.cn}}
#     }

# %%
# link http://www.openslr.org/47/
# !wget http://www.openslr.org/resources/47/primewords_md_2018_set1.tar.gz
# Out:
# --2019-12-16 12:15:17--  http://www.openslr.org/resources/47/primewords_md_2018_set1.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9057625192 (8.4G) [application/x-gzip]
# Saving to: ‘primewords_md_2018_set1.tar.gz’
#
# ords_md_2018_set1.t  15%[==>                 ]   1.29G  19.4MB/s    eta 6m 18s ^C

# %%
# !mkdir /content/ch1
# !tar -C /content/ch1 -xf /content/primewords_md_2018_set1.tar.gz
# Out:
# gzip: stdin: unexpected end of file
# tar: Unexpected EOF in archive
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now

# %%
# !ls /content/ch1/primewords_md_2018_set1/audio_files/3/30 -1 | wc -l
# Out:
# 181

# %%
root_dir = '/content/ch1/primewords_md_2018_set1/audio_files/3/31'
clips = os.listdir(root_dir)
IPython.display.Audio(filename=os.path.join(root_dir, clips[random.randint(0, 181)]))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Good & long sentences.

# %% [markdown]
# ### ch2
#
# This corpus were recorded in silence in-door environment using cellphone. It has 855 speakers. Each speaker has 120 utterances. All utterances were carefully transcribed and checked by human. Transcription accuracy is guaranteed. If there is any problem, we agree to correct them for you. The corpus contains:
# 	audio files;
# 	transcriptions;
# 	metadata;
#
#
# Please cite the data as “ST-CMDS-20170001_1, Free ST Chinese Mandarin Corpus”.
#
#
# The data set is a subset of a much bigger data set which was recorded in the same environment as this open source data. Please visit our website www.surfing.ai for details.

# %%
# link http://www.openslr.org/38/
# !wget http://www.openslr.org/resources/38/ST-CMDS-20170001_1-OS.tar.gz
# Out:
# --2019-12-16 10:53:47--  http://www.openslr.org/resources/38/ST-CMDS-20170001_1-OS.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8231662593 (7.7G) [application/x-gzip]
# Saving to: ‘ST-CMDS-20170001_1-OS.tar.gz.1’
#
# ST-CMDS-20170001_1- 100%[===================>]   7.67G  16.6MB/s    in 6m 59s
#
# 2019-12-16 11:00:47 (18.7 MB/s) - ‘ST-CMDS-20170001_1-OS.tar.gz.1’ saved [8231662593/8231662593]

# %%
# !mkdir /content/ch2
# !tar -C /content/ch2 -xf /content/ST-CMDS-20170001_1-OS.tar.gz.1
# Out:
# mkdir: cannot create directory ‘/content/ch2’: File exists

# %%
# !ls /content/ch2/ST-CMDS-20170001_1-OS/ -1 | wc -l
# Out:
# 307800

# %%
root_dir = '/content/ch2/ST-CMDS-20170001_1-OS/'
clips = os.listdir(root_dir)
idx = random.randint(0, 307800)
while not 'wav' in clips[idx]:
    idx = random.randint(0, 307800)
with open(os.path.join(root_dir, clips[idx].replace('wav', 'txt'))) as f:
    data = f.read()
    print(data)
# play the audio
IPython.display.Audio(filename=os.path.join(root_dir, clips[idx]))
# Out:
# 亚卡巴全歼敌军一个半满编
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### GOOD

# %% [markdown]
# ### ch3
#
# The corpus aims to support researchers in speech recognition, machine translation, voiceprint recognition, and other speech-related fields. Therefore, the corpus is totally free for academic use.
#
# Please cite the corpus as “aidatatang_200zh, a free Chinese Mandarin speech corpus by Beijing DataTang Technology Co., Ltd ( www.datatang.com )”.
#
# The corpus is a subset of a much bigger data (free 1505 hours Chinese Mandarin speech corpus) set which was recorded in the same environment as this open source data. Please visit our website DataTang for more details.
#
# DataTang is a community of creators-of world-changers and future-builders. We're invested in collaborating with a diverse set of voices in the AI world, and are excited about working on large-scale projects. Beyond speech, we're providing multiple resources in image, and text. For more data, please visit [Product].

# %%
# !wget http://www.openslr.org/resources/62/aidatatang_200zh.tgz
# Out:
# --2019-12-16 11:48:33--  http://www.openslr.org/resources/62/aidatatang_200zh.tgz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18756983399 (17G) [application/x-gzip]
# Saving to: ‘aidatatang_200zh.tgz’
#
# aidatatang_200zh.tg   7%[>                   ]   1.30G  18.9MB/s    eta 15m 12s^C

# %%
# !mkdir /content/ch3
# !tar -C /content/ch3 -xf /content/aidatatang_200zh.tgz
# Out:
# mkdir: cannot create directory ‘/content/ch3’: File exists
#
# gzip: stdin: unexpected end of file
# tar: Unexpected EOF in archive
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now

# %%
# !ls /content/ch3/aidatatang_200zh/corpus/train -1 | wc -l
# !mkdir /content/ch3/aidatatang_200zh/corpus/train/G0141
# !tar -C /content/ch3/aidatatang_200zh/corpus/train/G0141 -xf /content/ch3/aidatatang_200zh/corpus/train/G0141.tar.gz
# Out:
# 45

# %%
# !ls /content/ch3/aidatatang_200zh/corpus/train/G0141/G0141/ -1 | wc -l
# Out:
# 1596

# %%
clips = os.listdir(root_dir)
idx = int(random.randint(0, 1596)) 
root_dir = '/content/ch3/aidatatang_200zh/corpus/train/G0141/G0141/'
# !sed -n '$idx' /content/ch3/aidatatang_200zh/transcript/aidatatang_200_zh_transcript.txt
while not 'wav' in clips[idx]:
    idx = random.randint(0, 1596)
IPython.display.Audio(filename=os.path.join(root_dir, clips[idx]))
# Out:
# sed: -e expression #1, char 3: missing command
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### GOOD

# %% [markdown]
# ### ch4
#
# About this resource:
# MAGICDATA Mandarin Chinese Read Speech Corpus was developed by MAGIC DATA Technology Co., Ltd. and freely published for non-commercial use.
#
# The contents and the corresponding descriptions of the corpus include:
#
#     The corpus contains 755 hours of speech data, which is mostly mobile recorded data.
#     1080 speakers from different accent areas in China are invited to participate in the recording.
#     The sentence transcription accuracy is higher than 98%.
#     Recordings are conducted in a quiet indoor environment.
#     The database is divided into training set, validation set, and testing set in a ratio of 51: 1: 2.
#     Detail information such as speech data coding and speaker information is preserved in the metadata file.
#     The domain of recording texts is diversified, including interactive Q&A, music search, SNS messages, home command and control, etc.
#     Segmented transcripts are also provided.
#
# The corpus aims to support researchers in speech recognition, machine translation, speaker recognition, and other speech-related fields. Therefore, the corpus is totally free for academic use.
#
# The corpus is a subset of a much bigger data ( 10566.9 hours Chinese Mandarin Speech Corpus ) set which was recorded in the same environment. Please feel free to contact us via business@magicdatatech.com for more details.
#
# Citation
#
# Please cite the corpus as "Magic Data Technology Co., Ltd., "http://www.imagicdatatech.com/index.php/home/dataopensource/data_info/id/101", 05/2019".

# %%
# link http://www.openslr.org/68/
# !wget http://www.openslr.org/resources/68/dev_set.tar.gz
# Out:
# --2019-12-16 11:00:51--  http://www.openslr.org/resources/68/dev_set.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1035537823 (988M) [application/x-gzip]
# Saving to: ‘dev_set.tar.gz’
#
# dev_set.tar.gz      100%[===================>] 987.57M  18.7MB/s    in 55s
#
# 2019-12-16 11:01:46 (18.0 MB/s) - ‘dev_set.tar.gz’ saved [1035537823/1035537823]

# %%
# !mkdir /content/ch4
# !tar -C /content/ch4 -xf /content/dev_set.tar.gz

# %%
# !ls /content/ch4/dev/5_1812 -1 | wc -l
# Out:
# 594

# %%
root_dir = '/content/ch4/dev/5_1812/'
clips = os.listdir(root_dir)
idx = int(random.randint(0, 500)) 
#df = pd.read_csv('/content/ch4/dev/TRANS.txt', delimiter='\t')
print(df['Transcription'].iloc[idx])
IPython.display.Audio(filename=os.path.join(root_dir, clips[idx]))
# Out:
# 播放唢呐的歌曲
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##### QUITE LARGE. REJECTED AS OF NOW.
